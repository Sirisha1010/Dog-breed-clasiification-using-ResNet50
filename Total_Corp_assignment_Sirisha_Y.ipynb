# %%
#Importing all the necessary libraries
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import decode_predictions
from keras.applications.resnet50 import preprocess_input

# %%
# re-size all the images to this
IMAGE_SIZE = [224, 224]

# %%
pip install zipfile36

# %%
# importing required modules 
from zipfile import ZipFile 
  
# specifying the zip file name 
file_name = '/content/drive/MyDrive/train.zip'
  
# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall('/content/drive/MyDrive/Train') 
    print('Done!')
# Out:
# Streaming output truncated to the last 5000 lines.
# 83be6d622ab74a5e7e08b53eb8fd566a.jpg           2017-09-29 06:41:22        10995
# 83c2d7419b0429b9fe953bc1b6cddbec.jpg           2017-09-29 06:41:22        36265
# 83cf7d7cd2a759a93e2ffd95bea9c6fb.jpg           2017-09-29 06:41:22        44022
# 83d405858f0931722ef21e8ac0adee4d.jpg           2017-09-29 06:41:22        36308
# 83d4125a4c3c7dc5956563276cb1cd74.jpg           2017-09-29 06:41:22        14772
# 83f0bb565b2186dbcc6a9d009cb26ff2.jpg           2017-09-29 06:41:22        54157
# 83fad0718581a696132c96c166472627.jpg           2017-09-29 06:41:22        36308
# 83fbbcc9a612e3f712b1ba199da61f20.jpg           2017-09-29 06:41:22        24727
# 8403d8936430c2f05ab7d74d23c2c0cb.jpg           2017-09-29 06:41:22        44122
# 8406d837b2d7fac1c3cd621abb4c4f9e.jpg           2017-09-29 06:41:22        24656
# 840b67d26e5e43f8eb6430f62d4ba1ac.jpg           2017-09-29 06:41:22        74691
# ...

# %%
# importing required modules 
from zipfile import ZipFile 
  
# specifying the zip file name 
file_name = '/content/drive/MyDrive/test.zip'
  
# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall('/content/drive/MyDrive/Test') 
    print('Done!')
# Out:
# Streaming output truncated to the last 5000 lines.
# 82e5e34cc18b267ef7057cc92de8b44b.jpg           2017-09-29 06:41:22         7563
# 82e64f28df4fff22beb11e9a1e413212.jpg           2017-09-29 06:41:22        42381
# 82ec6bdf968a14923340179515ce5546.jpg           2017-09-29 06:41:22        37080
# 82ee3ee4dc01b33203a049c6c3338034.jpg           2017-09-29 06:41:22        71504
# 82f07a63a1f03ff9d8e0f4a8458caa93.jpg           2017-09-29 06:41:22        32972
# 82f5fb0bdaff30a4a3374e2d9915856c.jpg           2017-09-29 06:41:22        71955
# 82fbff1bd375474e3d4ec5cbfde3f9f0.jpg           2017-09-29 06:41:22        40010
# 8301c772feb7f4068473f0157ae58f9b.jpg           2017-09-29 06:41:22        32300
# 8307be57a9d76c1584e16801a39cb1dc.jpg           2017-09-29 06:41:22         7304
# 831a38bd2cfa0a093967d5b6c1ac09dc.jpg           2017-09-29 06:41:22        38018
# 831ef824af939f9754e3593638933b64.jpg           2017-09-29 06:41:22        37443
# ...

# %%
#Reading the train extracted train dataset
train='/content/drive/MyDrive/Total_Corp/Train'

# %%
#Reading the train extracted test dataset
test='/content/drive/MyDrive/Total_Corp/Test'

# %%
#Reading the labels file
import pandas as pd
labels=pd.read_csv('/content/drive/MyDrive/Total_Corp/labels.csv')
labels.head()
# Out:
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
labels.shape
# Out:
# (10222, 2)

# %%
#Converting the "id" in labels csv to a filename by adding .jpg extension
labels['id'] = labels['id'].apply(lambda x: '{}.jpg'.format(x))

# %%
#Checking the top 5 rows
labels.head()
# Out:
#                                      id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07.jpg       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97.jpg             dingo
# 2  001cdf01b096e06d78e9e5112d419397.jpg          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d.jpg          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62.jpg  golden_retriever

# %%
# importing required modules 
from zipfile import ZipFile 
  
# specifying the zip file name 
file_name = '/content/drive/MyDrive/sample_submission.csv.zip'
  
# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall('/content/drive/MyDrive/Sample Submission') 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# sample_submission.csv                          2019-12-11 20:54:14     25200295
# Extracting all the files now...
# Done!

# %%
#Reading the sample submission file
submission=pd.read_csv("/content/drive/MyDrive/Total_Corp/Sample Submission/sample_submission.csv")
submission.head()
# Out:
#                                  id  ...  yorkshire_terrier
# 0  000621fb3cbb32d8935728e48679680e  ...           0.008333
# 1  00102ee9d8eb90812350685311fe5890  ...           0.008333
# 2  0012a730dfa437f5f3613fb75efcd4ce  ...           0.008333
# 3  001510bc8570bbeee98c8d80c8a95ec1  ...           0.008333
# 4  001a5f3114548acdefa3d4da05474c2e  ...           0.008333
#
# [5 rows x 121 columns]

# %%
submission['id'] = submission['id'].apply(lambda x: '{}.jpg'.format(x))
submission.head()
# Out:
#                                      id  ...  yorkshire_terrier
# 0  000621fb3cbb32d8935728e48679680e.jpg  ...           0.008333
# 1  00102ee9d8eb90812350685311fe5890.jpg  ...           0.008333
# 2  0012a730dfa437f5f3613fb75efcd4ce.jpg  ...           0.008333
# 3  001510bc8570bbeee98c8d80c8a95ec1.jpg  ...           0.008333
# 4  001a5f3114548acdefa3d4da05474c2e.jpg  ...           0.008333
#
# [5 rows x 121 columns]

# %%
#Converting the images into vector of values
datagen=ImageDataGenerator(rescale=1./255.,validation_split=0.25)

# %%
#Mapping the images in the train dataset to the labels
train_generator=datagen.flow_from_dataframe(
dataframe=labels,
directory='/content/drive/MyDrive/Total_Corp/Train/',
x_col="id",
y_col="breed",
subset="training",
batch_size=32,
seed=42,
shuffle=True,
class_mode="categorical",
target_size=(32,32))
# Out:
# Found 7667 validated image filenames belonging to 120 classes.

# %%
#Mapping the images in the validation dataset to the labels

valid_generator=datagen.flow_from_dataframe(
dataframe=labels,
directory="/content/drive/MyDrive/Total_Corp/Train/",
x_col="id",
y_col="breed",
subset="validation",
batch_size=32,
seed=42,
shuffle=True,
class_mode="categorical",
target_size=(32,32))
# Out:
# Found 2555 validated image filenames belonging to 120 classes.

# %%
test_datagen=ImageDataGenerator(rescale=1./255.)

# %%
#Mapping the images in the test dataset to none

test_generator=test_datagen.flow_from_dataframe(
dataframe=submission,
directory="/content/drive/MyDrive/Total_Corp/Test/",
x_col="id",
y_col=None,
batch_size=1,
seed=42,
shuffle=False,
class_mode=None,
target_size=(32,32))
# Out:
# Found 10357 validated image filenames.

# %%
n_categories = 10

# %%
categories=["beagle", "chihuahua", "doberman",
"french_bulldog","golden_retriever", "malamute", "pug", "saint_bernard", "scottish_deerhound",
"tibetan_mastiff"]
# Initialize ohe_labels as all zeros
one_labels = ____((len(labels['breed']), n_categories))

# %%
#Building ResNet50 model
res = ResNet50(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# %%
# our layers - you can add more if you want
x = Flatten()(res.output)
# x = Dense(1000, activation='relu')(x)
prediction = Dense(10, activation='softmax')(x)

# %%
# create a model object
model = Model(inputs=res.input, outputs=prediction)

# %%
# view the structure of the model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# ...

# %%
# tell the model what cost and optimization method to use
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)
